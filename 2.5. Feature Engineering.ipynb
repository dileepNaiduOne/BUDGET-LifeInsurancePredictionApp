# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import *
import xgboost as xgb

from sklearn.preprocessing import PowerTransformer


import warnings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("cleaned_df.csv")

df["Policy Start Date"] = pd.to_datetime(df["Policy Start Date"])

# %%
df.shape
# Out:
# (2000000, 31)

# %%
df.head()
# Out:
#     Age  Gender  Annual Income Marital Status  Number of Dependents  \
# 0  19.0  Female        10049.0        Married                   1.0
# 1  39.0  Female        31678.0       Divorced                   3.0
# 2  23.0    Male        25602.0       Divorced                   3.0
# 3  21.0    Male       141855.0        Married                   2.0
# 4  21.0    Male        39651.0         Single                   1.0
#
#   Education Level     Occupation  Health Score  Location    Policy Type  \
# 0      Bachelor's  Self-Employed     22.598761     Urban        Premium
# 1        Master's     Unemployed     15.569731     Rural  Comprehensive
# 2     High School  Self-Employed     47.177549  Suburban        Premium
# 3      Bachelor's  Self-Employed     10.938144     Rural          Basic
# 4      Bachelor's  Self-Employed     20.376094     Rural        Premium
#
#    Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# 0              2.0         17.0         372.0                 5.0
# 1              1.0         12.0         694.0                 2.0
# 2              1.0         14.0         632.0                 3.0
# 3              1.0          0.0         367.0                 1.0
# 4              0.0          8.0         598.0                 4.0
#
#            Policy Start Date Customer Feedback Smoking Status  \
# 0 2023-12-23 15:21:39.134960              Poor             No
# 1 2023-06-12 15:21:39.111551           Average            Yes
# 2 2023-09-30 15:21:39.221386              Good            Yes
# 3 2024-06-12 15:21:39.226954              Poor            Yes
# 4 2021-12-01 15:21:39.252145              Poor            Yes
#
#   Exercise Frequency Property Type  Premium Amount  IsNull_Age  \
# 0             Weekly         House          2869.0           0
# 1            Monthly         House          1483.0           0
# 2             Weekly         House           567.0           0
# 3              Daily     Apartment           765.0           0
# 4             Weekly         House          2022.0           0
#
#    IsNull_Annual Income  IsNull_Marital Status  IsNull_Number of Dependents  \
# 0                     0                      0                            0
# 1                     0                      0                            0
# 2                     0                      0                            0
# 3                     0                      0                            0
# 4                     0                      0                            0
#
#    IsNull_Occupation  IsNull_Health Score  IsNull_Previous Claims  \
# 0                  0                    0                       0
# 1                  1                    0                       0
# 2                  0                    0                       0
# 3                  1                    0                       0
# 4                  0                    0                       0
#
#    IsNull_Vehicle Age  IsNull_Credit Score  IsNull_Insurance Duration  \
# 0                   0                    0                          0
# 1                   0                    0                          0
# 2                   0                    1                          0
# 3                   0                    0                          0
# 4                   0                    0                          0
#
#    IsNull_Customer Feedback
# 0                         0
# 1                         0
# 2                         0
# 3                         0
# 4                         0

# %%
nulls = []
nuniques = []
uniques = []
types = []

for i in df.columns:
    nulls.append(df[i].isnull().sum())
    nuniques.append(df[i].nunique())
    uniques.append(df[i].unique())
    types.append(df[i].dtype)


pd.DataFrame(
    {
        "Column" : df.columns,
        "Data Type" : types,
        "Nulls" : nulls,
        "No. of Uniques" : nuniques,
        "Uniques" : uniques
    }
).sort_values(by="Nulls", ascending=False)
# Out:
#                          Column       Data Type   Nulls  No. of Uniques  \
# 19               Premium Amount         float64  800000            4794
# 1                        Gender          object       0               2
# 0                           Age         float64       0              47
# 3                Marital Status          object       0               3
# 4          Number of Dependents         float64       0               5
# 5               Education Level          object       0               4
# 2                 Annual Income         float64       0           97970
# 7                  Health Score         float64       0          933976
# 8                      Location          object       0               3
# 9                   Policy Type          object       0               3
# 10              Previous Claims         float64       0              10
# 11                  Vehicle Age         float64       0              20
# 12                 Credit Score         float64       0             550
# 13           Insurance Duration         float64       0               9
# 6                    Occupation          object       0               3
# 14            Policy Start Date  datetime64[ns]       0          173790
# 15            Customer Feedback          object       0               3
# 17           Exercise Frequency          object       0               4
# 16               Smoking Status          object       0               2
# 18                Property Type          object       0               3
# 20                   IsNull_Age           int64       0               2
# 21         IsNull_Annual Income           int64       0               2
# 22        IsNull_Marital Status           int64       0               2
# 23  IsNull_Number of Dependents           int64       0               2
# 24            IsNull_Occupation           int64       0               2
# 25          IsNull_Health Score           int64       0               2
# 26       IsNull_Previous Claims           int64       0               2
# 27           IsNull_Vehicle Age           int64       0               2
# 28          IsNull_Credit Score           int64       0               2
# 29    IsNull_Insurance Duration           int64       0               2
# 30     IsNull_Customer Feedback           int64       0               2
#
#                                               Uniques
# 19  [2869.0, 1483.0, 567.0, 765.0, 2022.0, 3202.0,...
# 1                                      [Female, Male]
# 0   [19.0, 39.0, 23.0, 21.0, 29.0, 41.0, 48.0, 44....
# 3                         [Married, Divorced, Single]
# 4                           [1.0, 3.0, 2.0, 0.0, 4.0]
# 5            [Bachelor's, Master's, High School, PhD]
# 2   [10049.0, 31678.0, 25602.0, 141855.0, 39651.0,...
# 7   [22.59876067181393, 15.569730989408043, 47.177...
# 8                            [Urban, Rural, Suburban]
# 9                     [Premium, Comprehensive, Basic]
# 10  [2.0, 1.0, 0.0, 3.0, 4.0, 5.0, 6.0, 7.0, 8.0, ...
# 11  [17.0, 12.0, 14.0, 0.0, 8.0, 4.0, 11.0, 10.0, ...
# 12  [372.0, 694.0, 632.0, 367.0, 598.0, 614.0, 807...
# 13      [5.0, 2.0, 3.0, 1.0, 4.0, 6.0, 8.0, 9.0, 7.0]
# 6               [Self-Employed, Unemployed, Employed]
# 14  [2023-12-23 15:21:39.134960, 2023-06-12 15:21:...
# 15                              [Poor, Average, Good]
# 17                   [Weekly, Monthly, Daily, Rarely]
# 16                                          [No, Yes]
# 18                          [House, Apartment, Condo]
# 20                                             [0, 1]
# 21                                             [0, 1]
# 22                                             [0, 1]
# 23                                             [0, 1]
# 24                                             [0, 1]
# 25                                             [0, 1]
# 26                                             [0, 1]
# 27                                             [0, 1]
# 28                                             [0, 1]
# 29                                             [0, 1]
# 30                                             [0, 1]

# %% [markdown]
# ---
# #
# # **Feature Engineering**
# ---

# %% [markdown]
# # Health Conscious Level

# %% [markdown]
# **Exercise Frequency** --> `['Weekly', 'Monthly', 'Daily', 'Rarely']`
#
# **Smoking Status** --> `['No', 'Yes']`
#
# **Health Score**
# - Poor --> (< 16.285503904803008)
# - Average --> (>= 16.285503904803008 & <= 33.959695457149195)
# - Good --> (> 33.959695457149195)
#
# **Age**
# - Poor --> (< 30)
# - Average --> (>= 30 & <= 53)
# - Good --> (> 53.0)

# %%
health_min_df = pd.DataFrame()

# %%
health_min_df["smoke"] = df["Smoking Status"].replace({"Yes" : 0, "No" : 1})

# %%
health_min_df["ex"] = df["Exercise Frequency"].replace({"Rarely" : 0, "Monthly" : 1, "Weekly" : 2, "Daily" : 3})

# %%
bins = [0, 30, 53, float('inf')]
labels = [0, 1, 2]

health_min_df["age"] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)

# %%
bins = [0, 16.285503904803008, 33.959695457149195, float('inf')]
labels = [0, 1, 2]

health_min_df["health"] = pd.cut(df['Health Score'], bins=bins, labels=labels, right=False)

# %%
df["Health Conscious Level"] = health_min_df.sum(axis=1)

# %%
df["Health Conscious Level1"] = df["Smoking Status"].replace({"Yes" : 2, "No" : 4}) * df["Exercise Frequency"].replace({"Rarely" : 2, "Monthly" : 4, "Weekly" : 8, "Daily" : 16}) * df['Age'] * df['Health Score']

# %%
df.head(3)
# Out:
#     Age  Gender  Annual Income Marital Status  Number of Dependents  \
# 0  19.0  Female        10049.0        Married                   1.0
# 1  39.0  Female        31678.0       Divorced                   3.0
# 2  23.0    Male        25602.0       Divorced                   3.0
#
#   Education Level     Occupation  Health Score  Location    Policy Type  \
# 0      Bachelor's  Self-Employed     22.598761     Urban        Premium
# 1        Master's     Unemployed     15.569731     Rural  Comprehensive
# 2     High School  Self-Employed     47.177549  Suburban        Premium
#
#    Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# 0              2.0         17.0         372.0                 5.0
# 1              1.0         12.0         694.0                 2.0
# 2              1.0         14.0         632.0                 3.0
#
#            Policy Start Date Customer Feedback Smoking Status  \
# 0 2023-12-23 15:21:39.134960              Poor             No
# 1 2023-06-12 15:21:39.111551           Average            Yes
# 2 2023-09-30 15:21:39.221386              Good            Yes
#
#   Exercise Frequency Property Type  Premium Amount  IsNull_Age  \
# 0             Weekly         House          2869.0           0
# 1            Monthly         House          1483.0           0
# 2             Weekly         House           567.0           0
#
#    IsNull_Annual Income  IsNull_Marital Status  IsNull_Number of Dependents  \
# 0                     0                      0                            0
# 1                     0                      0                            0
# 2                     0                      0                            0
#
#    IsNull_Occupation  IsNull_Health Score  IsNull_Previous Claims  \
# 0                  0                    0                       0
# 1                  1                    0                       0
# 2                  0                    0                       0
#
#    IsNull_Vehicle Age  IsNull_Credit Score  IsNull_Insurance Duration  \
# 0                   0                    0                          0
# 1                   0                    0                          0
# 2                   0                    1                          0
#
#    IsNull_Customer Feedback  Health Conscious Level  Health Conscious Level1
# 0                         0                       4             13740.046488
# 1                         0                       2              4857.756069
# 2                         0                       4             17361.338138

# %% [markdown]
# #
# ---
# #

# %% [markdown]
# # Money Per Head

# %%
df["Money Per Head"] = df["Annual Income"] / df["Number of Dependents"].where(df["Number of Dependents"] != 0, 1)

# %%
df.head(3)
# Out:
#     Age  Gender  Annual Income Marital Status  Number of Dependents  \
# 0  19.0  Female        10049.0        Married                   1.0
# 1  39.0  Female        31678.0       Divorced                   3.0
# 2  23.0    Male        25602.0       Divorced                   3.0
#
#   Education Level     Occupation  Health Score  Location    Policy Type  \
# 0      Bachelor's  Self-Employed     22.598761     Urban        Premium
# 1        Master's     Unemployed     15.569731     Rural  Comprehensive
# 2     High School  Self-Employed     47.177549  Suburban        Premium
#
#    Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# 0              2.0         17.0         372.0                 5.0
# 1              1.0         12.0         694.0                 2.0
# 2              1.0         14.0         632.0                 3.0
#
#            Policy Start Date Customer Feedback Smoking Status  \
# 0 2023-12-23 15:21:39.134960              Poor             No
# 1 2023-06-12 15:21:39.111551           Average            Yes
# 2 2023-09-30 15:21:39.221386              Good            Yes
#
#   Exercise Frequency Property Type  Premium Amount  IsNull_Age  \
# 0             Weekly         House          2869.0           0
# 1            Monthly         House          1483.0           0
# 2             Weekly         House           567.0           0
#
#    IsNull_Annual Income  IsNull_Marital Status  IsNull_Number of Dependents  \
# 0                     0                      0                            0
# 1                     0                      0                            0
# 2                     0                      0                            0
#
#    IsNull_Occupation  IsNull_Health Score  IsNull_Previous Claims  \
# 0                  0                    0                       0
# 1                  1                    0                       0
# 2                  0                    0                       0
#
#    IsNull_Vehicle Age  IsNull_Credit Score  IsNull_Insurance Duration  \
# 0                   0                    0                          0
# 1                   0                    0                          0
# 2                   0                    1                          0
#
#    IsNull_Customer Feedback  Health Conscious Level  Health Conscious Level1  \
# 0                         0                       4             13740.046488
# 1                         0                       2              4857.756069
# 2                         0                       4             17361.338138
#
#    Money Per Head
# 0    10049.000000
# 1    10559.333333
# 2     8534.000000

# %% [markdown]
# #
# ---
# #

# %% [markdown]
# # Money Handling Level

# %%
df["Money Handling Level"] = df["Annual Income"] * df["Credit Score"]

# %%
df["Money Handling Level1"] = df["Annual Income"] / df["Credit Score"]

# %%
df.head(3)
# Out:
#     Age  Gender  Annual Income Marital Status  Number of Dependents  \
# 0  19.0  Female        10049.0        Married                   1.0
# 1  39.0  Female        31678.0       Divorced                   3.0
# 2  23.0    Male        25602.0       Divorced                   3.0
#
#   Education Level     Occupation  Health Score  Location    Policy Type  \
# 0      Bachelor's  Self-Employed     22.598761     Urban        Premium
# 1        Master's     Unemployed     15.569731     Rural  Comprehensive
# 2     High School  Self-Employed     47.177549  Suburban        Premium
#
#    Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# 0              2.0         17.0         372.0                 5.0
# 1              1.0         12.0         694.0                 2.0
# 2              1.0         14.0         632.0                 3.0
#
#            Policy Start Date Customer Feedback Smoking Status  \
# 0 2023-12-23 15:21:39.134960              Poor             No
# 1 2023-06-12 15:21:39.111551           Average            Yes
# 2 2023-09-30 15:21:39.221386              Good            Yes
#
#   Exercise Frequency Property Type  Premium Amount  IsNull_Age  \
# 0             Weekly         House          2869.0           0
# 1            Monthly         House          1483.0           0
# 2             Weekly         House           567.0           0
#
#    IsNull_Annual Income  IsNull_Marital Status  IsNull_Number of Dependents  \
# 0                     0                      0                            0
# 1                     0                      0                            0
# 2                     0                      0                            0
#
#    IsNull_Occupation  IsNull_Health Score  IsNull_Previous Claims  \
# 0                  0                    0                       0
# 1                  1                    0                       0
# 2                  0                    0                       0
#
#    IsNull_Vehicle Age  IsNull_Credit Score  IsNull_Insurance Duration  \
# 0                   0                    0                          0
# 1                   0                    0                          0
# 2                   0                    1                          0
#
#    IsNull_Customer Feedback  Health Conscious Level  Health Conscious Level1  \
# 0                         0                       4             13740.046488
# 1                         0                       2              4857.756069
# 2                         0                       4             17361.338138
#
#    Money Per Head  Money Handling Level  Money Handling Level1
# 0    10049.000000             3738228.0              27.013441
# 1    10559.333333            21984532.0              45.645533
# 2     8534.000000            16180464.0              40.509494

# %% [markdown]
# #
# ---
# #

# %% [markdown]
# # Growth

# %%
df["Growth"] = df["Education Level"].replace({"High School" : 1, "Bachelor's" : 2, "Master's" : 3, "PhD" : 4}) * df["Annual Income"]

# %%
df["Growth1"] = df["Annual Income"] / df["Education Level"].replace({"High School" : 1, "Bachelor's" : 2, "Master's" : 3, "PhD" : 4})

# %%
df.head(3)
# Out:
#     Age  Gender  Annual Income Marital Status  Number of Dependents  \
# 0  19.0  Female        10049.0        Married                   1.0
# 1  39.0  Female        31678.0       Divorced                   3.0
# 2  23.0    Male        25602.0       Divorced                   3.0
#
#   Education Level     Occupation  Health Score  Location    Policy Type  \
# 0      Bachelor's  Self-Employed     22.598761     Urban        Premium
# 1        Master's     Unemployed     15.569731     Rural  Comprehensive
# 2     High School  Self-Employed     47.177549  Suburban        Premium
#
#    Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# 0              2.0         17.0         372.0                 5.0
# 1              1.0         12.0         694.0                 2.0
# 2              1.0         14.0         632.0                 3.0
#
#            Policy Start Date Customer Feedback Smoking Status  \
# 0 2023-12-23 15:21:39.134960              Poor             No
# 1 2023-06-12 15:21:39.111551           Average            Yes
# 2 2023-09-30 15:21:39.221386              Good            Yes
#
#   Exercise Frequency Property Type  Premium Amount  IsNull_Age  \
# 0             Weekly         House          2869.0           0
# 1            Monthly         House          1483.0           0
# 2             Weekly         House           567.0           0
#
#    IsNull_Annual Income  IsNull_Marital Status  IsNull_Number of Dependents  \
# 0                     0                      0                            0
# 1                     0                      0                            0
# 2                     0                      0                            0
#
#    IsNull_Occupation  IsNull_Health Score  IsNull_Previous Claims  \
# 0                  0                    0                       0
# 1                  1                    0                       0
# 2                  0                    0                       0
#
#    IsNull_Vehicle Age  IsNull_Credit Score  IsNull_Insurance Duration  \
# 0                   0                    0                          0
# 1                   0                    0                          0
# 2                   0                    1                          0
#
#    IsNull_Customer Feedback  Health Conscious Level  Health Conscious Level1  \
# 0                         0                       4             13740.046488
# 1                         0                       2              4857.756069
# 2                         0                       4             17361.338138
#
#    Money Per Head  Money Handling Level  Money Handling Level1   Growth  \
# 0    10049.000000             3738228.0              27.013441  20098.0
# 1    10559.333333            21984532.0              45.645533  95034.0
# 2     8534.000000            16180464.0              40.509494  25602.0
#
#         Growth1
# 0   5024.500000
# 1  10559.333333
# 2  25602.000000

# %% [markdown]
# #
# ---
# #

# %% [markdown]
# # Determinstic

# %%
df["Determinstic"] = df["Annual Income"] * (1 / df["Age"])

# %%
df.head(3)
# Out:
#     Age  Gender  Annual Income Marital Status  Number of Dependents  \
# 0  19.0  Female        10049.0        Married                   1.0
# 1  39.0  Female        31678.0       Divorced                   3.0
# 2  23.0    Male        25602.0       Divorced                   3.0
#
#   Education Level     Occupation  Health Score  Location    Policy Type  \
# 0      Bachelor's  Self-Employed     22.598761     Urban        Premium
# 1        Master's     Unemployed     15.569731     Rural  Comprehensive
# 2     High School  Self-Employed     47.177549  Suburban        Premium
#
#    Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# 0              2.0         17.0         372.0                 5.0
# 1              1.0         12.0         694.0                 2.0
# 2              1.0         14.0         632.0                 3.0
#
#            Policy Start Date Customer Feedback Smoking Status  \
# 0 2023-12-23 15:21:39.134960              Poor             No
# 1 2023-06-12 15:21:39.111551           Average            Yes
# 2 2023-09-30 15:21:39.221386              Good            Yes
#
#   Exercise Frequency Property Type  Premium Amount  IsNull_Age  \
# 0             Weekly         House          2869.0           0
# 1            Monthly         House          1483.0           0
# 2             Weekly         House           567.0           0
#
#    IsNull_Annual Income  IsNull_Marital Status  IsNull_Number of Dependents  \
# 0                     0                      0                            0
# 1                     0                      0                            0
# 2                     0                      0                            0
#
#    IsNull_Occupation  IsNull_Health Score  IsNull_Previous Claims  \
# 0                  0                    0                       0
# 1                  1                    0                       0
# 2                  0                    0                       0
#
#    IsNull_Vehicle Age  IsNull_Credit Score  IsNull_Insurance Duration  \
# 0                   0                    0                          0
# 1                   0                    0                          0
# 2                   0                    1                          0
#
#    IsNull_Customer Feedback  Health Conscious Level  Health Conscious Level1  \
# 0                         0                       4             13740.046488
# 1                         0                       2              4857.756069
# 2                         0                       4             17361.338138
#
#    Money Per Head  Money Handling Level  Money Handling Level1   Growth  \
# 0    10049.000000             3738228.0              27.013441  20098.0
# 1    10559.333333            21984532.0              45.645533  95034.0
# 2     8534.000000            16180464.0              40.509494  25602.0
#
#         Growth1  Determinstic
# 0   5024.500000    528.894737
# 1  10559.333333    812.256410
# 2  25602.000000   1113.130435

# %% [markdown]
# #
# ---
# #

# %% [markdown]
# # Some Dummy Features

# %%
df["Day_Name"] = df["Policy Start Date"].dt.day_name()

# %%
df["Credit by Score"] = df["Credit Score"]/df["Previous Claims"].where(df["Previous Claims"] != 0, 1)

# %%
df['CreditInsurance'] = df['Credit Score'] * df['Insurance Duration']

# %%
df['Health_Risk_Score'] = df['Smoking Status'].apply(lambda x: 1 if x == 'Smoker' else 0) + df['Exercise Frequency'].apply(lambda x: 1 if x == 'Low' else (0.5 if x == 'Medium' else 0)) + (100 - df['Health Score']) / 20

# %%
df['Credit_Health_Score'] = df['Credit Score'] * df['Health Score']
df['Health_Age_Interaction'] = df['Health Score'] * df['Age']

# %% [markdown]
# #
# ---
# #

# %% [markdown]
# # Customer Feedback

# %%
df["Feedback1"] = df["Annual Income"] * df["Customer Feedback"].replace({"Poor" : 2, "Average" : 4, "Good" : 8})

# %%
df["Feedback2"] = df["Credit Score"] * df["Customer Feedback"].replace({"Poor" : 2, "Average" : 4, "Good" : 8})

# %%
df["Feedback3"] = df["Previous Claims"] * df["Customer Feedback"].replace({"Poor" : 2, "Average" : 4, "Good" : 8})

# %%
df["Feedback4"] = df["Health Score"] * df["Customer Feedback"].replace({"Poor" : 2, "Average" : 4, "Good" : 8})

# %% [markdown]
# #
# ---
# # Downloading the Df

# %%
df.to_csv("EDAed_df.csv", index=False)
